# %%
import numpy as np
import sys
sys.path.append('/usr/local/lib/python2.7/site-packages')
import cv2
import matplotlib.pyplot as plt
#from scipy import signal
#from skimage import data
#from skimage.feature import register_translation
#from skimage.feature.register_translation import _upsampled_dft
#from scipy.ndimage import fourier_shift
#sys.path.append('/usr/local/lib/python2.7/site-packages')
#from skimage import data
#from skimage.feature import register_translation
#from skimage.feature.register_translation import _unsampled_dft



# %matplotlib inline

#f, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2,3)
arr = []
arr = np.loadtxt('bigimage.txt', unpack = 'true')
arr0 = np.reshape(arr, [480,480])
#ax1.set_title('Total NV')
#ax1.imshow(arr0, extent = [0,480, 0, 480])
plt.imshow(arr0, label = "large scan")


arr1 = []
arr1 = np.loadtxt('smallimage.txt', unpack = 'true')
arr2 = np.reshape(arr1, [80,80])
#ax2.set_title('Subset of NVs')
#ax2.imshow(arr2, extent = [0,80,0,80])
#plt.imshow(arr2, label = 'small scan')

#arr3 = []
#arr3 = np.rot90(arr2)
#ax3.set_title('rotated image')
#ax3.imshow(arr3, extent = [0,80,0,80])


#arr4 = []
#arr4 = np.loadtxt('large1800.txt', unpack = 'true')
#arr5 = np.reshape(arr4, [800,800])
#ax4.set_title("Sample image large")
#ax4.imshow(arr4, extent = [0,800,0,800])


#image = data.camera()
#shift = (-22.4, 13.32)
# The shift corresponds to the pixel offset relative to the reference image
#offset_image = fourier_shift(np.fft.fftn(image), shift)
#offset_image = np.fft.ifftn(offset_image)
#print("Known offset (y, x): {}".format(shift))

# pixel precision first
#shift, error, diffphase = register_translation(image, offset_image)

#fig = plt.figure(figsize=(8, 3))
#ax1 = plt.subplot(1, 3, 1, adjustable='box-forced')
#ax2 = plt.subplot(1, 3, 2, sharex=ax1, sharey=ax1, adjustable='box-forced')
#ax3 = plt.subplot(1, 3, 3)

#ax1.imshow(image, cmap='gray')
#ax1.set_axis_off()
#ax1.set_title('Reference image')

#ax2.imshow(offset_image.real, cmap='gray')
#ax2.set_axis_off()
#ax2.set_title('Offset image')

# Show the output of a cross-correlation to show what the algorithm is
# doing behind the scenes
#image_product = np.fft.fft2(image) * np.fft.fft2(offset_image).conj()
#cc_image = np.fft.fftshift(np.fft.ifft2(image_product))
#ax3.imshow(cc_image.real)
#ax3.set_axis_off()
#ax3.set_title("Cross-correlation")

#plt.show()

#print("Detected pixel offset (y, x): {}".format(shift))

# subpixel precision
#shift, error, diffphase = register_translation(image, offset_image, 100)

#fig = plt.figure(figsize=(8, 3))
#ax1 = plt.subplot(1, 3, 1, adjustable='box-forced')
#ax2 = plt.subplot(1, 3, 2, sharex=ax1, sharey=ax1, adjustable='box-forced')
#ax3 = plt.subplot(1, 3, 3)

#ax1.imshow(image, cmap='gray')
#ax1.set_axis_off()
#ax1.set_title('Reference image')

#ax2.imshow(offset_image.real, cmap='gray')
#ax2.set_axis_off()
#ax2.set_title('Offset image')

# Calculate the upsampled DFT, again to show what the algorithm is doing
# behind the scenes.  Constants correspond to calculated values in routine.
# See source code for details.
#cc_image = _upsampled_dft(image_product, 150, 100, (shift*100)+75).conj()
#ax3.imshow(cc_image.real)
#ax3.set_axis_off()
#ax3.set_title("Supersampled XC sub-area")


#print("Detected subpixel offset (y, x): {}".format(shift))

# %%
import numpy as np
import sys
sys.path.append('/usr/local/lib/python2.7/site-packages')
import cv2
print cv2.__version__
# Out:
# 2.4.13.2

# %%
import numpy as np
import sys
sys.path.append('/usr/local/lib/python2.7/site-packages')
import cv2
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, show

#fig, ((ax1)) = plt.subplots(1,1)


arr = []
arr = np.loadtxt('bigimage.txt', unpack = 'true')
#print len(arr)
arr0 = np.reshape(arr, [480,480])
fig = plt.imshow(arr0, interpolation = 'nearest')
plt.set_cmap('nipy_spectral')
plt.axis('off')
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)
plt.savefig('largescan.png', bbox_inches='tight', pad_inches = 0)
plt.close(f)

# %%
import numpy as np
import sys
sys.path.append('/usr/local/lib/python2.7/site-packages')
import cv2
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, show

#fig, ((ax1)) = plt.subplots(1,1)


arr = []
arr = np.loadtxt('smallimage.txt', unpack = 'true')
#print len(arr)
arr0 = np.reshape(arr, [80,80])
fig = plt.imshow(arr0, interpolation = 'nearest')
plt.set_cmap('nipy_spectral')
plt.axis('off')
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)
plt.savefig('smallscan.png', bbox_inches='tight', pad_inches = 0)
plt.close(f)

# %%
import numpy as np
import sys
sys.path.append('/usr/local/lib/python2.7/site-packages')
import cv2
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, show

#fig, ((ax1)) = plt.subplots(1,1)


arr = []
arr = np.loadtxt('smallimage.txt', unpack = 'true')

arr0 = np.reshape(arr, [80,80])
arr0 = np.rot90(arr0)
fig = plt.imshow(arr0, interpolation = 'nearest')
plt.set_cmap('nipy_spectral')
plt.axis('off')
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)
plt.savefig('smallscanrotated.png', bbox_inches='tight', pad_inches = 0)
plt.close(f)
